# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
pd.DataFrame([np.mean(random.sample([1,2,3,4,5,6],3)) for i in range(100)]).plot()
plt.plot(range(100),[3.5]*100)

# %%
pd.DataFrame([np.mean([np.mean(random.sample([1,2,3,4,5,6],3)) for i in range(100)]) for j in range(30)]).plot()
plt.plot(range(40),[3.5]*40)
np.mean([np.mean([np.mean(random.sample([1,2,3,4,5,6],3)) for i in range(100)]) for j in range(30)])
# Out:
# 3.5112222222222225

# %%
a=np.array([[1,2,3],[1,2,3],[1,2,3]])

# %%
s,v,d=np.linalg.svd(a)

# %%
s,v,d
# Out:
# (array([[-0.57735027, -0.57735027, -0.57735027],
#         [-0.57735027, -0.21132487,  0.78867513],
#         [-0.57735027,  0.78867513, -0.21132487]]),
#  array([6.4807407, 0.       , 0.       ]),
#  array([[-0.26726124, -0.53452248, -0.80178373],
#         [ 0.        , -0.83205029,  0.5547002 ],
#         [ 0.96362411, -0.14824986, -0.22237479]]))

# %%
np.dot(np.dot(s,v),np.transpose(d))
# Out:
# array([ 6.        ,  1.03774904, -2.21880078])

# %%
np.dot(s,np.transpose(s))
# Out:
# array([[ 1.00000000e+00, -4.11566787e-17, -1.42594996e-16],
#        [-4.11566787e-17,  1.00000000e+00,  2.48721418e-17],
#        [-1.42594996e-16,  2.48721418e-17,  1.00000000e+00]])

# %%
np.dot(d,np.transpose(d))
# Out:
# array([[ 1.00000000e+00,  1.30160619e-17, -5.30255252e-17],
#        [ 1.30160619e-17,  1.00000000e+00,  1.48379687e-17],
#        [-5.30255252e-17,  1.48379687e-17,  1.00000000e+00]])

# %%
np.dot(s,v)#,np.transpose(d))
# Out:
# array([-3.74165739, -3.74165739, -3.74165739])

# %%
np.transpose(d)
# Out:
# array([[-0.26726124,  0.        ,  0.96362411],
#        [-0.53452248, -0.83205029, -0.14824986],
#        [-0.80178373,  0.5547002 , -0.22237479]])

# %%
b=np.array([[1,2],[2,3]])

# %%
b
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
np.dot(b,b)
# Out:
# array([[ 5,  8],
#        [ 8, 13]])

# %%
s
# Out:
# array([[-0.57735027, -0.57735027, -0.57735027],
#        [-0.57735027, -0.21132487,  0.78867513],
#        [-0.57735027,  0.78867513, -0.21132487]])

# %%
v
# Out:
# array([6.4807407, 0.       , 0.       ])

# %%
np.dot(s,v)
# Out:
# array([-3.74165739, -3.74165739, -3.74165739])

# %%
s.dot(v.dot(d))
# Out:
# array([ 6.       , -2.3660254, -0.6339746])

# %%
A = np.array([[1, 2], [3, 4],[3, 4]])
print(A)
# Singular-value decomposition
U, s, VT = np.linalg.svd(A)
# create m x n Sigma matrix
Sigma = np.zeros((A.shape[0], A.shape[1]))
# populate Sigma with n x n diagonal matrix
Sigma[:A.shape[1], :A.shape[1]] = np.diag(s[:1])
# reconstruct matrix
B = U.dot(Sigma.dot(VT))
print(B)
# Out:
# [[1 2]
#  [3 4]
#  [3 4]]
# [[-6.79307243 -1.08222334]
#  [ 9.16077855  1.45942921]
#  [ 9.16077855  1.45942921]]

# %%
Sigma
# Out:
# array([[7.40635934, 0.        ],
#        [0.        , 0.3818917 ],
#        [0.        , 0.        ]])

# %%
Sigma[:A.shape[1], :A.shape[1]]
# Out:
# array([[7.40635934, 0.        ],
#        [0.        , 0.3818917 ]])

# %%
np.diag(s)
# Out:
# array([[7.40635934, 0.        ],
#        [0.        , 0.3818917 ]])

# %%
Sigma = np.zeros((A.shape[0], A.shape[1]))
Sigma
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
Sigma[:A.shape[1], :A.shape[1]]
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.diag(s[:1])
# Out:
# array([[7.40635934]])

# %%
s[:1]
# Out:
# array([7.40635934])

# %%
s
# Out:
# array([7.40635934, 0.3818917 ])
